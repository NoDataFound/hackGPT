# %%
#OpenAI banner
import fade
pwntxt= r"""
                :                                                    :
            ─ ──+──── ──  ─                                ─  ── ────+── ─
               _|_____   __   __  ___  _____  ___        __        _.|     
              |   __ "\ |"  |/  \|  "|(\"   \|"  \      /""\      |" \    
              (. |__) :)|'  /    \:  ||.\\   \    |    /    \     ||  |   
              |:  ____/ |: /'        ||: \.   \\  |   /' /\  \    |:  |   
              (|  /      \//  /\'    ||.  \    \. |  //  __'  \   |.  |   
             /|__/ \     /   /  \\   ||    \    \ | /   /  \\  \  /\  |\  
            (_______)   |___/    \___| \___|\____\)(___/    \___)(__\_|_) 
                |                                                    |
            ─ ──+──── ──  ─                                ─  ── ────+── ─                                  
                :                                                    :  
╔─────────────────────────────-= OPEN API Notebook=-─────────────────── ¤ ◎ ¤ ──────╗
║  ┌¤───────────────────────────────────┬────────────────────────Requirements───┐   ║ 
╚──│  Format......: hax                 │  Payload..........: /input/           │───╝  
   │  Date........: Nov 11,1999         │  API Token......: [********--] .env   │
   ╚────────────────────────────────────┴───────────────────────────────────────╝"""
fadedpwn = fade.purplepink(pwntxt)
print(fadedpwn)
# Out:
#                 :                                                    :
#             ─ ──+──── ──  ─                                ─  ── ────+── ─
#                _|_____   __   __  ___  _____  ___        __        _.|
#               |   __ "\ |"  |/  \|  "|(\"   \|"  \      /""\      |" \
#               (. |__) :)|'  /    \:  ||.\\   \    |    /    \     ||  |
#               |:  ____/ |: /'        ||: \.   \\  |   /' /\  \    |:  |
#               (|  /      \//  /\'    ||.  \    \. |  //  __'  \   |.  |
#              /|__/ \     /   /  \\   ||    \    \ | /   /  \\  \  /\  |\
#             (_______)   |___/    \___| \___|\____\)(___/    \___)(__\_|_)
#                 |                                                    |
#             ─ ──+──── ──  ─                                ─  ── ────+── ─
#                 :                                                    :
# ╔─────────────────────────────-= OPEN API Notebook=-─────────────────── ¤ ◎ ¤ ──────╗
# ║  ┌¤───────────────────────────────────┬────────────────────────Requirements───┐   ║
# ╚──│  Format......: hax                 │  Payload..........: /input/           │───╝
#    │  Date........: Nov 11,1999         │  API Token......: [********--] .env   │
#    ╚────────────────────────────────────┴───────────────────────────────────────╝

# %%
#OpenAI API Setup
from dotenv import load_dotenv
import os
import fade
from pathlib import Path
import openai
import tweepy
# Load API key from an environment variable or secret management service

load_dotenv(".env")  
apiToken = os.environ.get('OPENAI_TOKEN')
openai.api_key = apiToken
API_KEY = os.getenv('twitter_api_key')
API_SECRET = os.getenv('twitter_api_secret')
ACCESS_TOKEN = os.getenv('twitter_access_token')
TOKEN_SECRET = os.getenv('twitter_token_secret')

if 'OPENAI_TOKEN' in os.environ:
   pass
else:
   error='''           
                     *   )           )            (   
                     `(     ( /((        (  (      )\   
                      )\(   )\())\  (    )\))(  ((((_) 
                     ((_)\ (_))((_) )\ ) ((   ))\  )\) 
                     8"""" 8"""8  8"""8  8"""88 8"""8  
                     8     8   8  8   8  8    8 8   8  
                     8eeee 8eee8e 8eee8e 8    8 8eee8e 
                     88    88   8 88   8 8    8 88   8 
                     88    88   8 88   8 8    8 88   8 
                     88eee 88   8 88   8 8eeee8 88   8 
                                  
   \033[1;33mAttempting to Set OpenAI system variable with API key.

                      \033[0;37mExample: \033[40m$ 𝚎𝚡𝚙𝚘𝚛𝚝 OPENAI_TOKEN="𝙰𝙸 𝚃𝚘𝚔𝚎𝚗"
                      \033[0;37mSee sample \033[40m.𝚎𝚗𝚟\033[0;37m file for formating.'''


   fadederror = fade.fire(error)
   print(fadederror)
   Path(".env").touch()
   setting_token = open(".env", "a")
   userkey = input('Enter OpenAI API Key: ').replace(" ","")
   setting_token.write("OPENAI_TOKEN="+'"'+userkey+'"\n')
   #print("API Setup Complete... continue to next step")
if 'twitter_api_key' in os.environ:
   pass
else:
   print("Set Twitter creds") 
   Path(".env").touch()
   setting_token = open(".env", "a")
   userkey = input('twitter_api_key: ').replace(" ","")
   setting_token.write("twitter_api_key="+'"'+userkey+'"\n')
   userkey = input('twitter_api_secret: ').replace(" ","")
   setting_token.write("twitter_api_secret="+'"'+userkey+'"\n')  
   userkey = input('twitter_access_token ').replace(" ","")
   setting_token.write("twitter_access_token="+'"'+userkey+'"\n')
   userkey = input('twitter_token_secret: ').replace(" ","")
   setting_token.write("twitter_token_secret="+'"'+userkey+'"')

# %%
#Single Lookups
import os
import openai
import json
import fade
from dotenv import load_dotenv
load_dotenv(".env")  
apiToken = os.environ.get('OPENAI_TOKEN')
openai.api_key = apiToken
payload = open("input/malware/malware_sample", "r").readlines()
payload = str(payload)
response = openai.Completion.create(
  model="code-davinci-002",
  prompt=payload+"\nHere's your loot:\n",
  temperature=0,
  max_tokens=64,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0,
  stop=["\"\"\""]
)
response = response['choices'][0]['text']
fadedresponse = fade.greenblue(response)


data_payload = "input/code"
search = open(data_payload ,"r")
#with open("datafile") as myfile:
head = [next(search) for x in range(15)]
head = fade.purpleblue(str(head))


fadedsearch =r"""
                                         
                  _____     _____          _____   ______         _____    ____ 
              ___|\    \   |\    \   _____|\    \ |\     \    ___|\    \  |    |
             |    |\    \  | |    | /    /|\\    \| \     \  /    /\    \ |    |
             |    | |    | \/     / |    || \|    \  \     ||    |  |    ||    |
             |    |/____/| /     /_  \   \/  |     \  |    ||    |__|    ||    |
             |    ||    |||     // \  \   \  |      \ |    ||    .--.    ||    |
             |    ||____|/|    |/   \ |    | |    |\ \|    ||    |  |    ||    |
             |____|       |\ ___/\   \|   /| |____||\_____/||____|  |____||____|
             |    |       | |   | \______/ | |    |/ \|   |||    |  |    ||    |
             |____|        \|___|/\ |    | | |____|   |___|/|____|  |____||____|
               \(             \(   \|____|/    \(       )/    \(      )/    \(  
                '              '      )/        '       '      '      '      '  
                                      '        
─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
 """ 
                                                     
tookewl=fade.purplepink(fadedsearch)
print(tookewl)


print("\033[36msearching OpenAI for:\n")
print("[snip]\n"+head+"[snip]")
seperator = "─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─"
faded_seperator = fade.water(seperator)
print(faded_seperator)
fadedresponse = fade.greenblue("1."+response)
print(' '*39+"🆁🅴🆂🆄🅻🆃🆂\n" + "𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:"+ data_payload)
print("\n\033[36mHere's what I think this code is doing:")
print(fadedresponse)
print(faded_seperator)

# %%
#Bulk OpenAI Search
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import fade
import json
import requests
import urllib.parse
import urllib.request
import argparse
import sys
import os
import json
import csv
import shutil
from os import path
from shutil import make_archive
from directory_structure import Tree
from alive_progress import alive_bar
import time
import openai
from dotenv import load_dotenv
load_dotenv()  
apiToken = os.environ.get("OPENAI_TOKEN")
headers = {
                    "Accept": "application/json; charset=utf-8",
                    "Authorization": "Token" + apiToken
                }
targets = "input/sample_sources"

search = open(targets ,"r")
query = search.read()
fadedsearch =r"""
                                         
                  _____     _____          _____   ______         _____    ____ 
              ___|\    \   |\    \   _____|\    \ |\     \    ___|\    \  |    |
             |    |\    \  | |    | /    /|\\    \| \     \  /    /\    \ |    |
             |    | |    | \/     / |    || \|    \  \     ||    |  |    ||    |
             |    |/____/| /     /_  \   \/  |     \  |    ||    |__|    ||    |
             |    ||    |||     // \  \   \  |      \ |    ||    .--.    ||    |
             |    ||____|/|    |/   \ |    | |    |\ \|    ||    |  |    ||    |
             |____|       |\ ___/\   \|   /| |____||\_____/||____|  |____||____|
             |    |       | |   | \______/ | |    |/ \|   |||    |  |    ||    |
             |____|        \|___|/\ |    | | |____|   |___|/|____|  |____||____|
               \(             \(   \|____|/    \(       )/    \(      )/    \(  
                '              '      )/        '       '      '      '      '  
                                      '        
─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
 """ 
                                                     
tookewl=fade.purplepink(fadedsearch)
print(tookewl)

query_parse = json.dumps(query.split("\n"), sort_keys=True, indent=4)
print("\033[36msearching OpenAI for")
print(query_parse)
seperator = "─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─"
faded_seperator = fade.water(seperator)
print(faded_seperator)
openai_targets = []

if 'OPENAI_TOKEN' in os.environ:
    pass
else:
    os.environ['OPENAI_TOKEN'] = input('Enter API Key: ').replace(" ","")
investigation = input("Enter name for your investigation: ")
f_jsonpath = 'output/'+investigation+'/results'
token = os.environ.get("OPENAI_TOKEN")

os.mkdir('output/'+investigation)
os.mkdir('output/'+investigation+'/results/')

with open(targets, 'r') as targets:
    for line in targets:
        openai_targets.append(line)
        
    
    for search in openai_targets:
        #search = search.strip()
        response = openai.Completion.create(
        model="text-davinci-002",
        prompt=search+"\n\n",
        temperature=0,
        max_tokens=3000,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0,
        stop=["\"\"\""]
        )
        response = response['choices'][0]['text']
        with open('output/'+investigation+'/results/'+str(search.rsplit('/', 1)[-1])+ ".txt", "w") as f:
            f.write(response)
        fadedresponse = fade.greenblue("1."+response)

        print(' '*39+"🆁🅴🆂🆄🅻🆃🆂\n" + "𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:"+ str(search).strip())
        print("\n\033[36mHere's your code! ")
        print(fadedresponse)
        print(faded_seperator)
        


path = Tree(f_jsonpath, absolute=False)
print(path)
# Out:
#
#                   _____     _____          _____   ______         _____    ____
#               ___|\    \   |\    \   _____|\    \ |\     \    ___|\    \  |    |
#              |    |\    \  | |    | /    /|\\    \| \     \  /    /\    \ |    |
#              |    | |    | \/     / |    || \|    \  \     ||    |  |    ||    |
#              |    |/____/| /     /_  \   \/  |     \  |    ||    |__|    ||    |
#              |    ||    |||     // \  \   \  |      \ |    ||    .--.    ||    |
#              |    ||____|/|    |/   \ |    | |    |\ \|    ||    |  |    ||    |
#              |____|       |\ ___/\   \|   /| |____||\_____/||____|  |____||____|
#              |    |       | |   | \______/ | |    |/ \|   |||    |  |    ||    |
#              |____|        \|___|/\ |    | | |____|   |___|/|____|  |____||____|
#                \(             \(   \|____|/    \(       )/    \(      )/    \(
#                 '              '      )/        '       '      '      '      '
#                                       '
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#
# searching OpenAI for
# [
#     "write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34878",
#     "write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34877",
#     "write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34821",
#     "write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34820",
#     "write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34819",
#     ""
# ]
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#                                        🆁🅴🆂🆄🅻🆃🆂
# 𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34878
#
# Here's what I think this code is doing:
# 1. It's importing the socket library
# 2. It's creating a socket object
# 3. It's connecting to the IP address and port number specified in the command line arguments
# 4. It's sending the string "Hello World" to the server
# 5. It's receiving 1024 bytes of data from the server
#
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#                                        🆁🅴🆂🆄🅻🆃🆂
# 𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34877
#
# Here's your code!
# 1.
# rule CVE_2022_34877 {
#
# meta:
#
# author = "seim"
#
# date = "2020-10-10"
#
# description = "Detects CVE-2022-34877"
#
# reference = "https://www.cvedetails.com/cve/CVE-2022-34877"
#
# hash = "6a6f0a8b8d0a8b8d0a8b8d0a8b8d0a8b"
#
# strings:
#
# $s1 = "CVE-2022-34877"
#
# $s2 = "https://www.cvedetails.com/cve/CVE-2022-34877"
#
# condition:
#
# all of them
#
# }
#
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#                                        🆁🅴🆂🆄🅻🆃🆂
# 𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34821
#
# Here's your code!
# 1.
# rule CVE_2022_34821 {
#
# meta:
#
# author = "seim"
#
# date = "2021-01-01"
#
# description = "Detects CVE-2022-34821"
#
# reference = "https://www.cvedetails.com/cve/CVE-2022-34821"
#
# hash = "6f8db3992107d3ecb4e0e37a5e0a3f6a"
#
#
#
# strings:
#
# $s1 = "CVE-2022-34821"
#
# $s2 = "https://www.cvedetails.com/cve/CVE-2022-34821"
#
#
#
# condition:
#
# $s1 or $s2
#
# }
#
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#                                        🆁🅴🆂🆄🅻🆃🆂
# 𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34820
#
# Here's your code!
# 1.
# rule CVE_2022_34820 {
#
# meta:
#
# author = "seim"
#
# date = "2020-10-01"
#
# description = "Detects CVE-2022-34820"
#
# reference = "https://www.cvedetails.com/cve/CVE-2022-34820"
#
# hash = "6a6f0a8b8d0a8b8d0a8b8d0a8b8d0a8b"
#
# strings:
#
# $s1 = "CVE-2022-34820"
#
# $s2 = "https://www.cvedetails.com/cve/CVE-2022-34820"
#
# condition:
#
# $s1 or $s2
#
# }
#
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#                                        🆁🅴🆂🆄🅻🆃🆂
# 𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:write a seim rule to detect https://www.cvedetails.com/cve/CVE-2022-34819
#
# Here's your code!
# 1.
# rule CVE_2022_34819 {
#
# meta:
#
# author = "seim"
#
# date = "2020-10-01"
#
# description = "Detects CVE-2022-34819"
#
# reference = "https://www.cvedetails.com/cve/CVE-2022-34819"
#
# hash = "6a6f0a8b8d0a8b8d0a8b8d0a8b8d0a8b"
#
# strings:
#
# $s1 = "CVE-2022-34819"
#
# $s2 = "https://www.cvedetails.com/cve/CVE-2022-34819"
#
# $s3 = "Affected products:"
#
# $s4 = "Vulnerable products:"
#
# $s5 = "Fixed in:"
#
# $s6 = "References:"
#
# $s7 = "Description"
#
# $s8 = "Details"
#
# $s9 = "Solution"
#
# $s10 = "Workarounds"
#
# $s11 = "Advisory URL"
#
# $s12 = "Advisory ID"
#
# $s13 = "CVE"
#
# $s14 = "CVSS Score"
#
# $s15 = "CVSS Vector"
#
# $s16 = "CVSS3 Score"
#
# $s17 = "CVSS3 Vector"
#
# $s18 = "CWE"
#
# $s19 = "Exploitability Subscore"
#
# $s20 = "Impact Subscore"
#
# $s21 = "Vulnerability Type(s)"
#
# $s22 = "Publish Date"
#
# $s23 = "Update Date"
#
# $s24 = "Threat Level"
#
# $s25 = "Attack Vector"
#
# $s26 = "Attack Complexity"
#
# $s27 = "Privileges Required"
#
# $s28 = "User Interaction"
#
# $s29 = "Scope"
#
# $s30 = "Confidentiality Impact"
#
# $s31 = "Integrity Impact"
#
# $s32 = "Availability Impact"
#
# $s33 = "Base Score"
#
# $s34 = "Temporal Score"
#
# $s35 = "Environmental Score"
#
# $s36 = "Modified Score"
#
# $s37 = "Access Vector"
#
# $s38 = "Access Complexity"
#
# $s39 = "Authentication"
#
# $s40 = "Confidentiality Impact"
#
# $s41 = "Integrity Impact"
#
# $s42 = "Availability Impact"
#
# $s43 = "Source"
#
# $s44 = "Generated On"
#
# $s45 = "Vendor"
#
# $s46 = "Product"
#
# $s47 = "Version"
#
# $s48 = "Update"
#
# $s49 = "Edition"
#
# $s50 = "Language"
#
# $s51 = "Software Type"
#
# $s52 = "Hardware Type"
#
# $s53 = "Threat Type"
#
# $s54 = "Exploit Ease"
#
# $s55 = "Vulnerability Type(s)"
#
# $s56 = "Exploitability Score"
#
# $s57 = "Impact Score"
#
# $s58 = "Obtain All Privilege"
#
# $s59 = "Obtain User Privilege"
#
# $s60 = "Obtain Other Privilege"
#
# $s61 = "User Interaction Required"
#
# $s62 = "Scope Changed"
#
# $s63 = "Confidentiality Impact"
#
# $s64 = "Integrity Impact"
#
# $s65 = "Availability Impact"
#
# $s66 = "Integrity Requirement"
#
# $s67 = "Availability Requirement"
#
# $s68 = "Modification of a Resource"
#
# $s69 = "Read Data"
#
# $s70 = "Write Data"
#
# $s71 = "Execute Code"
#
# $s72 = "Gain Privileges"
#
# $s73 = "Loss of Data"
#
# $s74 = "Loss of Availability"
#
# $s75 = "Loss of Confidentiality"
#
# $s76 = "Loss of Integrity"
#
# $s77 = "Partial"
#
# $s78 = "Complete"
#
# $s79 = "None"
#
# $s80 = "Low"
#
# $s81 = "Medium"
#
# $s82 = "High"
#
# $s83 = "Not Defined"
#
# $s84 = "Un-changed"
#
# $s85 = "Changed"
#
# $s86 = "Local"
#
# $s87 = "Adjacent Network"
#
# $s88 = "Network"
#
# $s89 = "Required"
#
# $s90 = "None Required"
#
# $s91 = "Low"
#
# $s92 = "Medium"
#
# $s93 = "High"
#
# $s94 = "Not Defined"
#
# $s95 = "Un-changed"
#
# $s96 = "Changed"
#
# $s97 = "Un-changed"
#
# $s98 = "Changed"
#
# $s99 = "Un-changed"
#
# $s100 = "Changed"
#
# $s101 = "Un-changed"
#
# $s102 = "Changed"
#
# $s103 = "Un-changed"
#
# $s104 = "Changed"
#
# $s105 = "Un-changed"
#
# $s106 = "Changed"
#
# $s107 = "Un-changed"
#
# $s108 = "Changed"
#
# $s109 = "Un-changed"
#
# $s110 = "Changed"
#
# $s111 = "Un-changed"
#
# $s112 = "Changed"
#
# $s113 = "Un-changed"
#
# $s114 = "Changed"
#
# $s115 = "Un-changed"
#
# $s116 = "Changed"
#
# $s117 = "Un-changed"
#
# $s118 = "Changed"
#
# $s119 = "Un-changed"
#
# $s120 = "Changed"
#
# $s121 = "Un-changed"
#
# $s122 = "Changed"
#
# $s123 = "Un-changed"
#
# $s124 = "Changed"
#
# $s125 = "Un-changed"
#
# $s126 = "Changed"
#
# $s127 = "Un-changed"
#
# $s128 = "Changed"
#
# $s129 = "Un-changed"
#
# $s130 = "Changed"
#
# $s131 = "Un-changed"
#
# $s132 = "Changed"
#
# $s133 = "Un-changed"
#
# $s134 = "Changed"
#
# $s135 = "Un-changed"
#
# $s136 = "Changed"
#
# $s137 = "Un-changed"
#
# $s138 = "Changed"
#
# $s139 = "Un-changed"
#
# $s140 = "Changed"
#
# $s141 = "Un-changed"
#
# $s142 = "Changed"
#
# $s143 = "Un-changed"
#
# $s144 = "Changed"
#
# $s145 = "Un-changed"
#
# $s146 = "Changed"
#
# $s147 = "Un-changed"
#
# $s148 = "Changed"
#
# $s149 = "Un-changed"
#
# $s150 = "Changed"
#
# $s151 = "Un-changed"
#
# $s152 = "Changed"
#
# $s153 = "Un-changed"
#
# $s154 = "Changed"
#
# $s155 = "Un-changed"
#
# $s156 = "Changed"
#
# $s157 = "Un-changed"
#
# $s158 = "Changed"
#
# $s159 = "Un-changed"
#
# $s160 = "Changed"
#
# $s161 = "Un-changed"
#
# $s162 = "Changed"
#
# $s163 = "Un-changed"
#
# $s164 = "Changed"
#
# $s165 = "Un-changed"
#
# $s166 = "Changed"
#
# $s167 = "Un-changed"
#
# $s168 = "Changed"
#
# $s169 = "Un-changed"
#
# $s170 = "Changed"
#
# $s171 = "Un-changed"
#
# $s172 = "Changed"
#
# $s173 = "Un-changed"
#
# $s174 = "Changed"
#
# $s175 = "Un-changed"
#
# $s176 = "Changed"
#
# $s177 = "Un-changed"
#
# $s178 = "Changed"
#
# $s179 = "Un-changed"
#
# $s180 = "Changed"
#
# $s181 = "Un-changed"
#
# $s182 = "Changed"
#
# $s183 = "Un-changed"
#
# $s184 = "Changed"
#
# $s185 = "Un-changed"
#
# $s186 = "Changed"
#
# $s187 = "Un-changed"
#
# $s188 = "Changed"
#
# $s189 = "Un-changed"
#
# $s190 = "Changed"
#
# $s191 = "Un-changed"
#
# $s192 = "Changed"
#
# $s193 = "Un-changed"
#
# $s194 = "Changed"
#
# $s195 = "Un-changed"
#
# $s196 = "Changed"
#
# $s197 = "Un-changed"
#
# $s198 = "Changed"
#
# $s199 = "Un-changed"
#
# $s200 = "Changed"
#
# $s201 = "Un-changed"
#
# $s202 = "Changed"
#
# $s203 = "Un-changed"
#
# $s204 = "Changed"
#
# $s205 = "Un-changed"
#
# $s206 = "Changed"
#
# $s207 = "Un-changed"
#
# $s208 = "Changed"
#
# $s209 = "Un-changed"
#
# $s210 = "Changed"
#
# $s211 = "Un-changed"
#
# $s212 = "Changed"
#
# $s213 = "Un-changed"
#
# $s214 = "Changed"
#
# $s215 = "Un-changed"
#
# $s216 = "Changed"
#
# $s217 = "Un-changed"
#
# $s218 = "Changed"
#
# $s219 = "Un-changed"
#
# $s220 = "Changed"
#
# $s221 = "Un-changed"
#
# $s222 = "Changed"
#
# $s223 = "Un-changed"
#
# $s224 = "Changed"
#
# $s225 = "Un-changed"
#
# $s226 = "Changed"
#
# $s227 = "Un-changed"
#
# $s228 = "Changed"
#
# $s229 = "Un-changed"
#
# $s230 = "Changed"
#
# $s231 = "Un-changed"
#
# $s232 = "Changed"
#
# $s233 = "Un-changed"
#
# $s234 = "Changed"
#
# $s235 = "Un-changed"
#
# $s236 = "Changed"
#
# $s237 = "Un-changed"
#
# $s238 = "Changed"
#
# $s239 = "Un-changed"
#
# $s240 = "Changed"
#
# $s241 = "Un-changed"
#
# $s242 = "Changed"
#
# $s243 = "Un-changed"
#
# $s244 = "Changed"
#
# $s245 = "Un-changed"
#
# $s246 = "Changed"
#
# $s247 = "Un-changed"
#
# $s248 = "Changed"
#
# $s249 = "Un-changed"
#
# $s250 = "Changed"
#
# $s251 = "Un-changed"
#
# $s252 = "Changed"
#
# $s253 = "Un-changed"
#
# $s254 = "Changed"
#
# $s255 = "Un-changed"
#
# $s256 = "Changed"
#
# $s257 = "Un-changed"
#
# $s258 = "Changed"
#
# $s259 = "Un-changed"
#
# $s260 = "Changed"
#
# $s261 = "Un-changed"
#
# $s262 = "Changed"
#
# $s263 = "Un-changed"
#
# $s264 = "Changed"
#
# $s265 = "Un-changed"
#
# $s266 = "Changed"
#
# $s267 = "Un-changed"
#
# $s268 = "Changed"
#
# $s269 = "Un-changed"
#
# $s270 = "Changed"
#
# $s271 = "Un-changed"
#
# $s272 = "Changed"
#
# $s273 = "Un-changed"
#
# $s274 = "Changed"
#
# $s275 = "Un-changed"
#
# $s276 = "Changed"
#
# $s277 = "Un-changed"
#
# $s278 = "Changed"
#
# $s279 = "Un-changed"
#
# $s280 = "
#
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
# 📂 results
# |_📄 CVE-2022-34878
# .txt
# |_📄 CVE-2022-34819
# .txt
# |_📄 CVE-2022-34820
# .txt
# |_📄 CVE-2022-34877
# .txt
# |_📄 CVE-2022-34821
# .txt

# %%
#Twitter Search ChatGPT tweeter
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import fade
import tweepy
import json
import requests
import urllib.parse
import urllib.request
import argparse
import sys
import os
import json
import csv
import shutil
from os import path
from shutil import make_archive
from directory_structure import Tree
from alive_progress import alive_bar
import time
from time import time, sleep
from datetime import date
import openai
from dotenv import load_dotenv
load_dotenv()  
openai.api_key= os.environ.get("OPENAI_TOKEN")
apiToken = os.environ.get("OPENAI_TOKEN")
API_KEY = os.getenv('twitter_api_key')
API_SECRET = os.getenv('twitter_api_secret')
ACCESS_TOKEN = os.getenv('twitter_access_token')
TOKEN_SECRET = os.getenv('twitter_token_secret')
auth = tweepy.OAuthHandler(str(API_KEY), str(API_SECRET))
auth.set_access_token(str(ACCESS_TOKEN), str(TOKEN_SECRET))

targets = "input/twitter"
date_since = date.today()
numtweets = 5 

search = open(targets ,"r")
query = search.read()
fadedsearch =r"""
                                         
                  _____     _____          _____   ______         _____    ____ 
              ___|\    \   |\    \   _____|\    \ |\     \    ___|\    \  |    |
             |    |\    \  | |    | /    /|\\    \| \     \  /    /\    \ |    |
             |    | |    | \/     / |    || \|    \  \     ||    |  |    ||    |
             |    |/____/| /     /_  \   \/  |     \  |    ||    |__|    ||    |
             |    ||    |||     // \  \   \  |      \ |    ||    .--.    ||    |
             |    ||____|/|    |/   \ |    | |    |\ \|    ||    |  |    ||    |
             |____|       |\ ___/\   \|   /| |____||\_____/||____|  |____||____|
             |    |       | |   | \______/ | |    |/ \|   |||    |  |    ||    |
             |____|        \|___|/\ |    | | |____|   |___|/|____|  |____||____|
               \(             \(   \|____|/    \(       )/    \(      )/    \(  
                '              '      )/        '       '      '      '      '  
                                      '        
─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
 """ 
                                                     
tookewl=fade.purplepink(fadedsearch)
print(tookewl)

query_parse = json.dumps(query.split("\n"), sort_keys=True, indent=4)
print("\033[36msearching twitter for")
print(query_parse)
seperator = "─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─"
faded_seperator = fade.water(seperator)
print(faded_seperator)
openai_targets = []
tweets = []
if 'OPENAI_TOKEN' in os.environ:
    pass
else:
    os.environ['OPENAI_TOKEN'] = input('Enter OpenAI API Key: ').replace(" ","")
#investigation = input("Enter name for your investigation: ")
#f_jsonpath = 'output/'+investigation+'/results'
token = os.environ.get("OPENAI_TOKEN")

#os.mkdir('output/'+investigation)
#os.mkdir('output/'+investigation+'/results/')

headers = {
                    "Accept": "application/json; charset=utf-8",
                    "Authorization": "Token" + apiToken
                }

with open(targets, 'r') as targets:
    
    for line in targets:
        openai_targets.append(line)

    api = tweepy.API(auth, wait_on_rate_limit = True)
    starttime = time()    
    for tweet in api.search_tweets(q = openai_targets, count = numtweets, lang = "en", until = date_since):
        tweets.append(tweet.text)
                #try:
        #print(tweets)    
        #api.update_status(
                #status="This tweet was generated by #PwnAI #ChatGPT:",
                #in_reply_to_status_id=tweet.id,
                #)
    for search in tweets:
        #search = search.strip()
        response = openai.Completion.create(
  model="text-davinci-003",
  prompt="\nCreate an analogy for this phrase:"+search+"\n1.",
  temperature=0.5,
  max_tokens=60,
  top_p=1,
  frequency_penalty=0,
  presence_penalty=0
)
        response = response['choices'][0]['text']
        #with open('output/'+investigation+'/results/'+str(search.rsplit('/', 1)[-1])+ ".txt", "w") as f:
        #    f.write(response)
        fadedresponse = fade.greenblue(response)
        api.update_status(
            status="Generated by #PwnAI #ChatGPT: I searched for #hacking & found a guide to help, I think it means: - "+response)
        print(' '*39+"🆁🅴🆂🆄🅻🆃🆂\n" + "𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:"+ str(search).strip('\n\n'))
        print("\033[36mHere's what I think these tweets mean:")
        print(fadedresponse)
        print(faded_seperator)
        
        
                #api.update_status(
                #status="Please reach us via DM",
                #in_reply_to_status_id=tweet.id,
                #)
                # #tweet.retweet()
                #print(tweet.retweet())
                #except:
                #print(e.reason)
                    #break # Only retweet the first one
            #sleep(60.0 - ((time() - starttime) % 60.0))    


#path = Tree(f_jsonpath, absolute=False)
#print(path)
# Out:
#
#                   _____     _____          _____   ______         _____    ____
#               ___|\    \   |\    \   _____|\    \ |\     \    ___|\    \  |    |
#              |    |\    \  | |    | /    /|\\    \| \     \  /    /\    \ |    |
#              |    | |    | \/     / |    || \|    \  \     ||    |  |    ||    |
#              |    |/____/| /     /_  \   \/  |     \  |    ||    |__|    ||    |
#              |    ||    |||     // \  \   \  |      \ |    ||    .--.    ||    |
#              |    ||____|/|    |/   \ |    | |    |\ \|    ||    |  |    ||    |
#              |____|       |\ ___/\   \|   /| |____||\_____/||____|  |____||____|
#              |    |       | |   | \______/ | |    |/ \|   |||    |  |    ||    |
#              |____|        \|___|/\ |    | | |____|   |___|/|____|  |____||____|
#                \(             \(   \|____|/    \(       )/    \(      )/    \(
#                 '              '      )/        '       '      '      '      '
#                                       '
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#
# searching twitter for
# [
#     "#hacking"
# ]
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
#
#                                        🆁🅴🆂🆄🅻🆃🆂
# 𝘚𝘦𝘢𝘳𝘤𝘩 𝘴𝘰𝘶𝘳𝘤𝘦 𝘪𝘯𝘱𝘶𝘵:If your Gmail account got Hacked, text me now for guide on how to recover your account immediately #gmailhack… https://t.co/hcOLT4sX0m
# Here's what I think these tweets mean:
#  It's like your car got stolen and you need help finding it - text me now for a guide on how to get it back quickly. #carstolen
#
# ─ ──+──── ──  ─   ────────────────────────────────────────────────────────   ─  ── ────+── ─
